# %%
import openai
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())
client = openai.Client()

# %%
def add_assistant_message(chat, content):
    chat.append({'role': 'assistant', 'content': content})
    return chat

def add_user_message(chat, content, model='gpt-3.5-turbo-0125', max_tokens=500, temperature=0):
    chat.append({'role': 'user', 'content': content})
    generate_response(chat, model, max_tokens, temperature)
    return chat

def generate_response(chat, model='gpt-3.5-turbo-0125', max_tokens=500, temperature=0):
    response = client.chat.completions.create(
        messages = chat,
        model = model,
        max_tokens = max_tokens,
        temperature = temperature
    )
    add_assistant_message(chat, response.choices[0].message.content)
    
def print_chat(chat):
    for message in chat:
        role = message['role']
        content = message['content']
        if role == 'user': said = 'asked'
        else: said = 'awnsered'
        print(f"{role} said: {content}", end='\n'+('-'*40)+'\n')

# %%
myChat = []
while True:
    text = input()
    if text == 'STOP': break
    print(chr(27) + "[2J") # limpa o terminal
    myChat = add_user_message(myChat, text)
    print_chat(myChat)
# Out:
# user said: onde fica o museu do frevo?
# ----------------------------------------
# assistant said: O Museu do Frevo fica localizado na cidade de Recife, no estado de Pernambuco, Brasil. O endereço é Praça do Arsenal da Marinha, s/n - Bairro do Recife.
# ----------------------------------------
#
# user said: onde fica o museu do frevo?
# ----------------------------------------
# assistant said: O Museu do Frevo fica localizado na cidade de Recife, no estado de Pernambuco, Brasil. O endereço é Praça do Arsenal da Marinha, s/n - Bairro do Recife.
# ----------------------------------------
# user said: o que mais posso conhecer lá perto?
# ----------------------------------------
# assistant said: Próximo ao Museu do Frevo, na cidade de Recife, há diversas atrações turísticas e culturais que você pode conhecer, como:
#
# 1. Marco Zero: localizado no Bairro do Recife, é um dos pontos turísticos mais famosos da cidade, onde você pode apreciar a vista da cidade e do Rio Capibaribe.
#
# 2. Paço do Frevo: um espaço cultural dedicado à preservação e difusão do frevo, localizado no Bairro do Recife.
#
# 3. Cais do Sertão: um museu dedicado à cultura nordestina, com exposições sobre a vida e obra do cantor e compositor Luiz Gonzaga.
#
# 4. Casa da Cultura: antiga prisão transformada em centro cultural, onde você pode encontrar lojas de artesanato, apresentações culturais e exposições.
#
# 5. Mercado de São José: um dos mercados mais tradicionais da cidade, onde você pode encontrar produtos locais, artesanato e gastronomia típica.
#
# Essas são apenas algumas das atrações que você pode conhecer na região próxima ao Museu do Frevo em Recife. A cidade oferece uma rica diversidade cultural e histórica para os visitantes explorarem.
# ----------------------------------------
#
# user said: onde fica o museu do frevo?
# ----------------------------------------
# assistant said: O Museu do Frevo fica localizado na cidade de Recife, no estado de Pernambuco, Brasil. O endereço é Praça do Arsenal da Marinha, s/n - Bairro do Recife.
# ----------------------------------------
# user said: o que mais posso conhecer lá perto?
# ----------------------------------------
# assistant said: Próximo ao Museu do Frevo, na cidade de Recife, há diversas atrações turísticas e culturais que você pode conhecer, como:
#
# 1. Marco Zero: localizado no Bairro do Recife, é um dos pontos turísticos mais famosos da cidade, onde você pode apreciar a vista da cidade e do Rio Capibaribe.
#
# 2. Paço do Frevo: um espaço cultural dedicado à preservação e difusão do frevo, localizado no Bairro do Recife.
#
# 3. Cais do Sertão: um museu dedicado à cultura nordestina, com exposições sobre a vida e obra do cantor e compositor Luiz Gonzaga.
#
# 4. Casa da Cultura: antiga prisão transformada em centro cultural, onde você pode encontrar lojas de artesanato, apresentações culturais e exposições.
#
# 5. Mercado de São José: um dos mercados mais tradicionais da cidade, onde você pode encontrar produtos locais, artesanato e gastronomia típica.
#
# Essas são apenas algumas das atrações que você pode conhecer na região próxima ao Museu do Frevo em Recife. A cidade oferece uma rica diversidade cultural e histórica para os visitantes explorarem.
# ----------------------------------------
# user said: onde comer no recife antigo em 10 palavras?
# ----------------------------------------
# assistant said: 1. Bodega de Veio
# 2. Oficina do Sabor
# 3. Parraxaxá
# 4. Laça Burguer
# 5. Bar Central
# 6. Entre Amigos
# 7. Beijupirá
# 8. Chiwake
# 9. Coco Bambu
# 10. Boteco Porto Ferreiro
# ----------------------------------------
#
# user said: onde fica o museu do frevo?
# ----------------------------------------
# assistant said: O Museu do Frevo fica localizado na cidade de Recife, no estado de Pernambuco, Brasil. O endereço é Praça do Arsenal da Marinha, s/n - Bairro do Recife.
# ----------------------------------------
# user said: o que mais posso conhecer lá perto?
# ----------------------------------------
# assistant said: Próximo ao Museu do Frevo, na cidade de Recife, há diversas atrações turísticas e culturais que você pode conhecer, como:
#
# 1. Marco Zero: localizado no Bairro do Recife, é um dos pontos turísticos mais famosos da cidade, onde você pode apreciar a vista da cidade e do Rio Capibaribe.
#
# 2. Paço do Frevo: um espaço cultural dedicado à preservação e difusão do frevo, localizado no Bairro do Recife.
#
# 3. Cais do Sertão: um museu dedicado à cultura nordestina, com exposições sobre a vida e obra do cantor e compositor Luiz Gonzaga.
#
# 4. Casa da Cultura: antiga prisão transformada em centro cultural, onde você pode encontrar lojas de artesanato, apresentações culturais e exposições.
#
# 5. Mercado de São José: um dos mercados mais tradicionais da cidade, onde você pode encontrar produtos locais, artesanato e gastronomia típica.
#
# Essas são apenas algumas das atrações que você pode conhecer na região próxima ao Museu do Frevo em Recife. A cidade oferece uma rica diversidade cultural e histórica para os visitantes explorarem.
# ----------------------------------------
# user said: onde comer no recife antigo em 10 palavras?
# ----------------------------------------
# assistant said: 1. Bodega de Veio
# 2. Oficina do Sabor
# 3. Parraxaxá
# 4. Laça Burguer
# 5. Bar Central
# 6. Entre Amigos
# 7. Beijupirá
# 8. Chiwake
# 9. Coco Bambu
# 10. Boteco Porto Ferreiro
# ----------------------------------------
# user said: stop
# ----------------------------------------
# assistant said: Desculpe se forneci informações demais. Se precisar de mais alguma coisa, estou à disposição. Como posso ajudar você hoje?
# ----------------------------------------
